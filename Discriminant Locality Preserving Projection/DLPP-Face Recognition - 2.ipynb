# %%
# 导入库函数
import numpy as np
import cv2
import os
import numpy as np
import pandas as pd
from scipy.sparse.linalg import eigs
import matplotlib.pyplot as plt

# %%
# LPP算法

Pi = 3.14159265358979323846

def knn_graph(Data, method, k):
    """
    计算k近邻图

    Args:
    - Data: 输入数据集的矩阵，每行代表一个样本点
    - k: 最近邻的数量

    Returns:
    - knn_adjacency_matrix: k近邻图的邻接矩阵，W[i, j]表示样本点i和j之间是否相连
    """
    # 获取样本点的数量
    n = Data.shape[0]
    # 初始化k近邻图的邻接矩阵
    knn_adjacency_matrix = np.zeros((n, n))  
    # 计算欧式距离矩阵
    distances = np.sqrt(np.sum((Data[:, None] - Data) ** 2, axis=2))
    if method == 'epsilon':
        return knn_adjacency_matrix, distances
    # 获取每个样本点的最近邻索引
    indices = np.argsort(distances, axis=1)[:, 1:k+1]
    # 构建k近邻图的权重矩阵
    # 遍历每个样本点的最近邻索引
    for i in range(n):
        knn_adjacency_matrix[i, indices[i]] = 1
        knn_adjacency_matrix[indices[i], i] = 1
    return knn_adjacency_matrix, distances

# 以每个点到其他所有点的平均值作为每个数据点的平均邻域半径
def compute_avg_radius(Data, distances): 
    n = Data.shape[0] # 数据集的大小
    radius = np.zeros(n) # 存储每个数据点的平均邻域半径
    for i in range(n): # 计算每个数据点的平均邻域半径
        avg_radius = np.mean(distances[i]) # 每个数据点到其他所有点的平均值
        radius[i] = avg_radius # 存储每个数据点的平均邻域半径
    return radius

# 计算k最近邻索引矩阵或epsilon邻接矩阵
def compute_neighborhood_matrix(Data, method, k):
    n = len(Data)
    knn_adjacency_matrix, distances = knn_graph(Data, method, k)
    if method == 'knn':
        return knn_adjacency_matrix, distances
    elif method == 'epsilon':
        adjacency_matrix = np.zeros((n, n))
        radius = compute_avg_radius(Data, distances)  # 计算每个数据点的邻域半径
        for i in range(n):  # 对于数据集中的每个样本点 i
            distances = np.sqrt(np.sum((Data[i] - Data) ** 2, axis=1))
            neighbors = []
            for j in range(n):  # 初始化 neighbors 列表
                if (distances[j] <= radius[i]) and (len(neighbors) <= n/2): # 如果样本点 j 在第i个样本点的epsilon邻域内
                    neighbors.append(j)
            adjacency_matrix[i, neighbors] = 1
            adjacency_matrix[neighbors, i] = 1
        return adjacency_matrix, distances

# 构建基于热核方法的权重矩阵
def construct_weight_matrix(Data, method, k, t):
    n = len(Data)
    Weight_matrix = np.zeros((n, n))
    adjacency_matrix, distances = compute_neighborhood_matrix(Data, method, k)
    if method == 'knn':
        # 计算相似度矩阵
        similarity_matrix = np.exp(-distances ** 2 / t)
        # 将相似度矩阵按照邻接矩阵进行筛选，得到需要设置权重的位置
        i_indices, j_indices = np.where(adjacency_matrix == 1)
        # 设置权重
        Weight_matrix[i_indices, j_indices] = similarity_matrix[i_indices, j_indices]
        Weight_matrix[j_indices, i_indices] = similarity_matrix[i_indices, j_indices]  # 对称矩阵
    elif method == 'epsilon':
        for i in range(n):  # 对于数据集中的每个样本点 i
            for j in range(n):  # 对于数据集中的每个样本点 j
                if adjacency_matrix[i, j] == 1:  # 如果样本点 j 在第i个样本点的epsilon邻域内
                    distance = np.linalg.norm(Data[i] - Data[j])  # 计算样本点 i 和 j 之间的距离（欧式距离）
                    Weight_matrix[i, j] = np.exp(-distance ** 2 / t) # 使用热核方法计算权重
                    Weight_matrix[j, i] = np.exp(-distance ** 2 / t) # 邻接矩阵为对称矩阵
    # 计算全局相似度
    '''
    修正权重矩阵的原理是利用全局相似度来修正局部相似度得到的权重矩阵，以使得整个权重矩阵更加平滑和连续。
    '''
    #print('adjacency_matrix:', adjacency_matrix.shape)
    #print('Weight_matrix:', Weight_matrix.shape)
    Weight_matrix += np.exp(-distances ** 2 / t)
    return Weight_matrix

# %%
# MLDA算法

# 计算每个类别的均值矩阵
def compute_classes_mean_matrix(train_data, train_labels):
    num_classes = len(np.unique(train_labels))  # 类别数量
    num_samples_per_class = train_data.shape[0] // num_classes  # 每个类别的样本数
    num_features = train_data.shape[1]  # 每个样本的特征维度
    
    means = np.zeros((num_classes, num_features))  # 存储每个类别的均值矩阵
    
    for i in range(1, num_classes + 1):  # 遍历每个类别
        temp_indices = np.where(train_labels == i)[0]  # 获取当前类别的训练数据索引
        temp_sum = np.sum(train_data[temp_indices], axis=0)  # 计算当前类别的特征值总和
        means[i-1] = temp_sum / num_samples_per_class  # 计算当前类别的均值
        
    return means  # 返回每个类别的均值矩阵

# 计算所有类别的整体均值矩阵
def compute_overall_mean_matrix(classes_means):
    overall_mean = np.mean(classes_means, axis=0)  # 计算所有类别的整体均值
    return overall_mean.reshape(-1, 1)  # 返回整体均值矩阵（转置）

# 计算中心类别矩阵
def compute_center_class_matrix(train_data, train_labels, classes_means):
    Z = np.zeros_like(train_data)  # 初始化中心类别矩阵
    
    for i in range(train_data.shape[0]):  # 遍历训练数据
        class_index = int(train_labels[i]) - 1  # 获取当前样本所属类别的索引
        Z[i] = train_data[i] - classes_means[class_index]  # 计算中心类别矩阵
        
    return Z  # 返回中心类别矩阵

# 计算类间散布矩阵
def compute_between_class_scatter_matrix(classes_means, overall_mean):
    n = 5  # 训练集与测试集的比例
    Sb = np.zeros((classes_means.shape[1], classes_means.shape[1]))  # 初始化类间散布矩阵
    for i in range(classes_means.shape[0]):  # 遍历每个类别的均值矩阵
        Sb = np.add(Sb, n * ((classes_means[i] - overall_mean) * (classes_means[i] - overall_mean).T))  # 计算类间散布矩阵
    return Sb  # 返回类间散布矩阵

# 计算类内散布矩阵
def compute_class_scatter_matrix(Z):
    Sw = np.dot(Z.T, Z)  # 计算类内散布矩阵
    return Sw  # 返回类内散布矩阵

# %%
def ShowEigenface(eigenfaces):
    # 显示前16个特征脸
    fig, axes = plt.subplots(4, 4, sharex=True, sharey=True, figsize=(8, 10))
    for i in range(16):
        axes[i%4][i//4].imshow(eigenfaces[:, i].reshape(112,92), cmap="gray")
    #print("显示特征脸")
    plt.show()

# %%
def LPP(Data, method, d, k, t):
    """
    进行LPP算法，得到特征映射后的数据集

    Args:
    - Data: 输入数据集的矩阵，每行代表一个样本点
    - d: 降维后的维度
    - k: 最近邻的数量
    - t: 高斯核函数的参数

    Returns:
    - selected_eigenvectors: 特征映射后的数据集
    - selected_eigenvalues: 特征值
    """
    Data = Data.T
    # Step 1: 计算权重矩阵
    Weight_matrix = construct_weight_matrix(Data, method, k, t)
    #print("权重矩阵形状：", Weight_matrix.shape)

    # Step 2: 计算度矩阵和拉普拉斯矩阵
    Degree_matrix = np.diag(np.sum(Weight_matrix, axis=1))
    Laplacian_matrix = Degree_matrix - Weight_matrix
    #print("拉普拉斯矩阵形状：", Laplacian_matrix.shape)
    
    return Laplacian_matrix

# %%
def MLDA(train_data, train_labels, d):
    """
    使用线性判别分析（LDA）进行特征提取。

    Args:
    - train_data: 训练数据集的特征矩阵
    - train_labels: 训练数据集的标签
    - d: 要提取的特征数量

    Returns:
    - selected_eigenvectors: 特征映射后的数据集
    - selected_eigenvalues: 特征值
    """
    # 计算每个类别的均值矩阵
    classes_means = compute_classes_mean_matrix(train_data, train_labels)
    #print('classes_means形状：', classes_means.shape)

    # 计算所有类别的整体均值矩阵
    overall_mean = compute_overall_mean_matrix(classes_means)
    #print('overall_mean形状：', overall_mean.shape)

    # 计算中心类别矩阵
    Z = compute_center_class_matrix(train_data, train_labels, classes_means)
    #print('Z形状：', Z.shape)

    # 计算类间散布矩阵
    Sb = compute_between_class_scatter_matrix(classes_means, overall_mean)
    #print('Sb形状：', Sb.shape)

    # 计算类内散布矩阵
    Sw = compute_class_scatter_matrix(Z)
    #print('Sw形状：', Sw.shape)
    
    return Sb, Sw, overall_mean

# %%
def DLPP(train_data, train_labels, d, lpp_method, k, t):
    # Step 1: 使用LDA进行特征提取
    Sb, Sw, overall_mean = MLDA(train_data, train_labels, d)

    # Step 2: 使用LPP进行特征提取
    Laplacian_matrix = LPP(train_data, lpp_method, d, k, t)

    # Step 3: 组合LPP和LDA的信息，构建目标函数的分子和分母
    numerator = np.dot(np.dot(train_data, Laplacian_matrix), train_data.T)
    denominator = np.dot(np.dot(train_data, Sb - Sw), train_data.T)
    
    # Step 4: 分式
    objective_value = numerator / denominator

    # Step 5: 求解广义特征值问题的特征值和特征向量
    eigenvalues, eigenvectors = eigs(objective_value, k=d+1, which='SR')
    sorted_indices = np.argsort(eigenvalues.real)
    selected_indices = sorted_indices[1:d + 1]
    selected_eigenvectors = eigenvectors.real[:, selected_indices]
    return selected_eigenvectors, overall_mean

# %%
# 读取第一张灰度图像的大小作为图片形状，如果有图像大小不符合要求则使用以下代码进行缩放
# img = cv2.resize(img, (128, 128), interpolation=cv2.INTER_AREA)

# 读取图像数据
def read_images(dataset_dir):
    data = []  # 存储图像数据的列表
    labels = []  # 存储标签的列表
    faceshape = [] # 存储图像形状
    for class_dir in os.listdir(dataset_dir):  # 遍历数据集文件夹中的文件夹（每个文件夹代表一个类别）
        class_path = os.path.join(dataset_dir, class_dir)  # 类别文件夹路径
        for file_name in os.listdir(class_path):  # 遍历每个类别文件夹中的图像文件
            file_path = os.path.join(class_path, file_name)  # 图像文件路径
            img = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)  # 读取灰度图像
            # 读取第一张灰度图像的大小作为图片形状
            faceshape = img.shape
            data.append(img.flatten())  # 将图像展平并添加到数据列表中
            labels.append(int(class_dir))  # 将类别标签添加到标签列表中
    return np.array(data), np.array(labels).reshape(-1, 1), faceshape  # 返回图像数据和标签

# 训练集和测试集划分
def train_test_split(data, labels, train_test_split_ratio):
    num_samples = data.shape[0]  # 总样本数
    train_samples = int(num_samples * train_test_split_ratio)  # 训练集样本数

    # 随机打乱数据集
    indices = np.random.permutation(num_samples)
    data = data[indices]
    labels = labels[indices]
    
    # 划分训练集和测试集
    train_data = data[:train_samples]
    train_labels = labels[:train_samples]
    test_data = data[train_samples:]
    test_labels = labels[train_samples:]
    
    return train_data, train_labels, test_data, test_labels

# %%
dataset = "attfaces"
data, labels, faceshape = read_images(dataset)
train_data, train_labels, test_data, test_labels = train_test_split(data, labels, train_test_split_ratio=0.5)
d = 40
k = 6000
t = 800000
lpp_method = 'knn'  # 'knn'或'epsilon'
dlpp_weight_matrix, overall_mean = DLPP(train_data, train_labels, d, lpp_method, k, t)
print("DLPP权重矩阵形状:", dlpp_weight_matrix.shape)

# %%
dlpp_eigenfaces = np.dot(train_data.T, dlpp_weight_matrix)
print("DLPP特征脸形状：", dlpp_eigenfaces.shape)
ShowEigenface(dlpp_eigenfaces)

# %%
def test_image(i, faceshape, overall_mean, train_labels, train_data, test_data, dlpp_eigenfaces, dlpp_weight_matrix):
    # 计算测试图像的权重向量
    #print("测试图像形状:", query.shape)
    #print("平均人脸形状:", overall_mean.shape)
    #print("特征脸形状:", dlpp_eigenfaces.shape)
    query = test_data[i]
    query_weight = (dlpp_eigenfaces.T @ (query - overall_mean.flatten()).reshape(-1, 1)).T
    #print("测试图像的权重形状:", query_weight.shape)
    #print("权重矩阵形状:", dlpp_weight_matrix.shape)
    
    # 计算测试图像与数据集中每个人脸的欧氏距离
    euclidean_distances = np.linalg.norm(dlpp_weight_matrix - query_weight, axis=0)
    # 找到最佳匹配的人脸
    best_match_index = np.argmin(euclidean_distances)
    #判断是否匹配正确
    flag = False
    if train_labels[best_match_index] == test_labels[i]:
        flag = True
    else:
        flag = False
    # 可视化
    '''
    fig, axes = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(8, 6))
    axes[0].imshow(query.reshape(faceshape), cmap="gray")
    axes[0].set_title("Query Image")
    axes[1].set_xlabel("Euclidean Distance: {:.0f}".format(euclidean_distances[best_match_index]))
    axes[1].imshow(train_data[best_match_index].reshape(faceshape), cmap="gray")
    axes[1].set_title("Best Match")
    plt.show()
    '''
    return flag

# %%
# 定义参数范围
d = 30
k_range = range(2000, 9001, 500)
t_range = range(10000, 1500001, 50000)
lpp_method = 'knn'

# 检查 CSV 文件是否存在
csv_filename = 'outcome2.csv'
if not os.path.exists(csv_filename):
    # 如果文件不存在，创建一个新的 DataFrame
    df = pd.DataFrame(columns=['k', 't', 'rate'])
else:
    # 如果文件存在，读取已有的结果
    df = pd.read_csv(csv_filename)

# 遍历参数
iteration = 1
for k in k_range:
    for t in t_range:
        # 检查结果是否已经存在
        if ((df['k'] == k) & (df['t'] == t)).any():
            continue  # 如果结果已经存在，跳过这个参数组合
        
        # 输出当前参数信息
        print(f"Iteration {iteration}: k={k}, t={t}")
        
        # 计算 DLPP
        dlpp_weight_matrix, overall_mean = DLPP(train_data, train_labels, d, lpp_method, k, t)
        dlpp_eigenfaces = np.dot(train_data.T, dlpp_weight_matrix)
        
        # 识别率统计
        wrong_times = 0
        right_times = 0
        for i in range(test_data.shape[0]):
            flag = test_image(i, faceshape, overall_mean, train_labels, train_data, test_data, dlpp_eigenfaces, dlpp_weight_matrix)
            if flag:
                right_times += 1
            else:
                wrong_times += 1
        rate = right_times / (right_times + wrong_times)
        print(f"Recognition Rate: {rate}")
        
        # 添加结果到 DataFrame
        df = pd.concat([df, pd.DataFrame({'k': [k], 't': [t], 'rate': [rate]})], ignore_index=True)

        # 保存结果到 CSV 文件
        df.to_csv(csv_filename, index=False)
         
        # 增加迭代计数
        iteration += 1
# Out:
# Iteration 1: k=2000, t=1310000
# C:\Users\Tony-Huang\AppData\Local\Temp\ipykernel_29700\3399071068.py:28: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   class_index = int(train_labels[i]) - 1  # 获取当前样本所属类别的索引
# Recognition Rate: 0.2
# Iteration 2: k=2000, t=1360000
# Recognition Rate: 0.2
# Iteration 3: k=2000, t=1410000
# Recognition Rate: 0.2
# Iteration 4: k=2000, t=1460000
# Recognition Rate: 0.2
# Iteration 5: k=2500, t=10000
# Recognition Rate: 0.16
# Iteration 6: k=2500, t=60000
# Recognition Rate: 0.2
# Iteration 7: k=2500, t=110000
# Recognition Rate: 0.2
# Iteration 8: k=2500, t=160000
# Recognition Rate: 0.2
# Iteration 9: k=2500, t=210000
# Recognition Rate: 0.2
# Iteration 10: k=2500, t=260000
# Recognition Rate: 0.2
# Iteration 11: k=2500, t=310000
# Recognition Rate: 0.2
# Iteration 12: k=2500, t=360000
# Recognition Rate: 0.2
# Iteration 13: k=2500, t=410000
# Recognition Rate: 0.2
# Iteration 14: k=2500, t=460000
# Recognition Rate: 0.2
# Iteration 15: k=2500, t=510000
# Recognition Rate: 0.2
# Iteration 16: k=2500, t=560000
# Recognition Rate: 0.2
# Iteration 17: k=2500, t=610000
# Recognition Rate: 0.2
# Iteration 18: k=2500, t=660000
# Recognition Rate: 0.2
# Iteration 19: k=2500, t=710000
# Recognition Rate: 0.2
# Iteration 20: k=2500, t=760000
# Recognition Rate: 0.2
# Iteration 21: k=2500, t=810000
# Recognition Rate: 0.2
# Iteration 22: k=2500, t=860000
# Recognition Rate: 0.2
# Iteration 23: k=2500, t=910000
# Recognition Rate: 0.2
# Iteration 24: k=2500, t=960000
# Recognition Rate: 0.2
# Iteration 25: k=2500, t=1010000
# Recognition Rate: 0.2
# Iteration 26: k=2500, t=1060000
# Recognition Rate: 0.2
# Iteration 27: k=2500, t=1110000
# Recognition Rate: 0.2
# Iteration 28: k=2500, t=1160000
# Recognition Rate: 0.2
# Iteration 29: k=2500, t=1210000
# Recognition Rate: 0.2
# Iteration 30: k=2500, t=1260000
# Recognition Rate: 0.2
# Iteration 31: k=2500, t=1310000
# Recognition Rate: 0.2
# Iteration 32: k=2500, t=1360000
# Recognition Rate: 0.2
# Iteration 33: k=2500, t=1410000
# Recognition Rate: 0.2
# Iteration 34: k=2500, t=1460000
# Recognition Rate: 0.2
# Iteration 35: k=3000, t=10000
# Recognition Rate: 0.16
# Iteration 36: k=3000, t=60000
# Recognition Rate: 0.2
# Iteration 37: k=3000, t=110000
# Recognition Rate: 0.2
# Iteration 38: k=3000, t=160000
# Recognition Rate: 0.2
# Iteration 39: k=3000, t=210000
# Recognition Rate: 0.2
# Iteration 40: k=3000, t=260000
# Recognition Rate: 0.2
# Iteration 41: k=3000, t=310000
# Recognition Rate: 0.2
# Iteration 42: k=3000, t=360000
# Recognition Rate: 0.2
# Iteration 43: k=3000, t=410000
# Recognition Rate: 0.2
# Iteration 44: k=3000, t=460000
# Recognition Rate: 0.2
# Iteration 45: k=3000, t=510000
# Recognition Rate: 0.2
# Iteration 46: k=3000, t=560000
# Recognition Rate: 0.2
# Iteration 47: k=3000, t=610000
# Recognition Rate: 0.2
# Iteration 48: k=3000, t=660000
# Recognition Rate: 0.2
# Iteration 49: k=3000, t=710000
# Recognition Rate: 0.2
# Iteration 50: k=3000, t=760000
# Recognition Rate: 0.2
# Iteration 51: k=3000, t=810000
# Recognition Rate: 0.2
# Iteration 52: k=3000, t=860000
# Recognition Rate: 0.2
# Iteration 53: k=3000, t=910000
# Recognition Rate: 0.2
# Iteration 54: k=3000, t=960000
# Recognition Rate: 0.2
# Iteration 55: k=3000, t=1010000
# Recognition Rate: 0.2
# Iteration 56: k=3000, t=1060000
# Recognition Rate: 0.2
# Iteration 57: k=3000, t=1110000
# Recognition Rate: 0.2
# Iteration 58: k=3000, t=1160000
# Recognition Rate: 0.2
# Iteration 59: k=3000, t=1210000
# Recognition Rate: 0.2
# Iteration 60: k=3000, t=1260000
# Recognition Rate: 0.2
# Iteration 61: k=3000, t=1310000
# Recognition Rate: 0.2
# Iteration 62: k=3000, t=1360000
# Recognition Rate: 0.2
# Iteration 63: k=3000, t=1410000
# Recognition Rate: 0.2
# Iteration 64: k=3000, t=1460000
# Recognition Rate: 0.2
# Iteration 65: k=3500, t=10000
# Recognition Rate: 0.18
# Iteration 66: k=3500, t=60000
# Recognition Rate: 0.2
# Iteration 67: k=3500, t=110000
# Recognition Rate: 0.2
# Iteration 68: k=3500, t=160000
# Recognition Rate: 0.2
# Iteration 69: k=3500, t=210000
# Recognition Rate: 0.2
# Iteration 70: k=3500, t=260000
# Recognition Rate: 0.2
# Iteration 71: k=3500, t=310000
# Recognition Rate: 0.2
# Iteration 72: k=3500, t=360000
# Recognition Rate: 0.2
# Iteration 73: k=3500, t=410000
# Recognition Rate: 0.2
# Iteration 74: k=3500, t=460000
# Recognition Rate: 0.2
# Iteration 75: k=3500, t=510000
# Recognition Rate: 0.2
# Iteration 76: k=3500, t=560000
# Recognition Rate: 0.2
# Iteration 77: k=3500, t=610000
# Recognition Rate: 0.2
# Iteration 78: k=3500, t=660000
# Recognition Rate: 0.2
# Iteration 79: k=3500, t=710000
# Recognition Rate: 0.2
# Iteration 80: k=3500, t=760000
# Recognition Rate: 0.2
# Iteration 81: k=3500, t=810000
# Recognition Rate: 0.2
# Iteration 82: k=3500, t=860000
# Recognition Rate: 0.2
# Iteration 83: k=3500, t=910000
# Recognition Rate: 0.2
# Iteration 84: k=3500, t=960000
# Recognition Rate: 0.2
# Iteration 85: k=3500, t=1010000
# Recognition Rate: 0.2
# Iteration 86: k=3500, t=1060000
# Recognition Rate: 0.2
# Iteration 87: k=3500, t=1110000
# Recognition Rate: 0.2
# Iteration 88: k=3500, t=1160000
# Recognition Rate: 0.2
# Iteration 89: k=3500, t=1210000
# Recognition Rate: 0.2
# Iteration 90: k=3500, t=1260000
# Recognition Rate: 0.2
# Iteration 91: k=3500, t=1310000
# Recognition Rate: 0.2
# Iteration 92: k=3500, t=1360000
# Recognition Rate: 0.2
# Iteration 93: k=3500, t=1410000
# Recognition Rate: 0.2
# Iteration 94: k=3500, t=1460000
# Recognition Rate: 0.2
# Iteration 95: k=4000, t=10000
# Recognition Rate: 0.18
# Iteration 96: k=4000, t=60000
# Recognition Rate: 0.2
# Iteration 97: k=4000, t=110000
# Recognition Rate: 0.2
# Iteration 98: k=4000, t=160000
# Recognition Rate: 0.2
# Iteration 99: k=4000, t=210000
# Recognition Rate: 0.2
# Iteration 100: k=4000, t=260000
# Recognition Rate: 0.2
# Iteration 101: k=4000, t=310000
# Recognition Rate: 0.2
# Iteration 102: k=4000, t=360000
# Recognition Rate: 0.2
# Iteration 103: k=4000, t=410000
# Recognition Rate: 0.2
# Iteration 104: k=4000, t=460000
# Recognition Rate: 0.2
# Iteration 105: k=4000, t=510000
# Recognition Rate: 0.2
# Iteration 106: k=4000, t=560000
# Recognition Rate: 0.2
# Iteration 107: k=4000, t=610000
# Recognition Rate: 0.2
# Iteration 108: k=4000, t=660000
# Recognition Rate: 0.2
# Iteration 109: k=4000, t=710000
# Recognition Rate: 0.2
# Iteration 110: k=4000, t=760000
# Recognition Rate: 0.2
# Iteration 111: k=4000, t=810000
# Recognition Rate: 0.2
# Iteration 112: k=4000, t=860000
# Recognition Rate: 0.2
# Iteration 113: k=4000, t=910000
# Recognition Rate: 0.2
# Iteration 114: k=4000, t=960000
# Recognition Rate: 0.2
# Iteration 115: k=4000, t=1010000
# Recognition Rate: 0.2
# Iteration 116: k=4000, t=1060000
# Recognition Rate: 0.2
# Iteration 117: k=4000, t=1110000
# Recognition Rate: 0.2
# Iteration 118: k=4000, t=1160000
# Recognition Rate: 0.2
# Iteration 119: k=4000, t=1210000
# Recognition Rate: 0.2
# Iteration 120: k=4000, t=1260000
# Recognition Rate: 0.2
# Iteration 121: k=4000, t=1310000
# Recognition Rate: 0.2
# Iteration 122: k=4000, t=1360000
# Recognition Rate: 0.2
# Iteration 123: k=4000, t=1410000
# Recognition Rate: 0.2
# Iteration 124: k=4000, t=1460000
# Recognition Rate: 0.2
# Iteration 125: k=4500, t=10000
# Recognition Rate: 0.18
# Iteration 126: k=4500, t=60000
# Recognition Rate: 0.2
# Iteration 127: k=4500, t=110000
# Recognition Rate: 0.2
# Iteration 128: k=4500, t=160000
# Recognition Rate: 0.2
# Iteration 129: k=4500, t=210000
# Recognition Rate: 0.2
# Iteration 130: k=4500, t=260000
# Recognition Rate: 0.2
# Iteration 131: k=4500, t=310000
# Recognition Rate: 0.2
# Iteration 132: k=4500, t=360000
# Recognition Rate: 0.2
# Iteration 133: k=4500, t=410000
# Recognition Rate: 0.2
# Iteration 134: k=4500, t=460000
# Recognition Rate: 0.2
# Iteration 135: k=4500, t=510000
# Recognition Rate: 0.2
# Iteration 136: k=4500, t=560000
# Recognition Rate: 0.2
# Iteration 137: k=4500, t=610000
# Recognition Rate: 0.2
# Iteration 138: k=4500, t=660000
# Recognition Rate: 0.2
# Iteration 139: k=4500, t=710000
# Recognition Rate: 0.2
# Iteration 140: k=4500, t=760000
# Recognition Rate: 0.2
# Iteration 141: k=4500, t=810000
# Recognition Rate: 0.2
# Iteration 142: k=4500, t=860000
# Recognition Rate: 0.2
# Iteration 143: k=4500, t=910000
# Recognition Rate: 0.2
# Iteration 144: k=4500, t=960000
# Recognition Rate: 0.2
# Iteration 145: k=4500, t=1010000
# Recognition Rate: 0.2
# Iteration 146: k=4500, t=1060000
# Recognition Rate: 0.2
# Iteration 147: k=4500, t=1110000
# Recognition Rate: 0.2
# Iteration 148: k=4500, t=1160000
# Recognition Rate: 0.2
# Iteration 149: k=4500, t=1210000
# Recognition Rate: 0.2
# Iteration 150: k=4500, t=1260000
# Recognition Rate: 0.2
# Iteration 151: k=4500, t=1310000
# Recognition Rate: 0.2
# Iteration 152: k=4500, t=1360000
# Recognition Rate: 0.2
# Iteration 153: k=4500, t=1410000
# Recognition Rate: 0.2
# Iteration 154: k=4500, t=1460000
# Recognition Rate: 0.2
# Iteration 155: k=5000, t=10000
# Recognition Rate: 0.18
# Iteration 156: k=5000, t=60000
# Recognition Rate: 0.2
# Iteration 157: k=5000, t=110000
# Recognition Rate: 0.2
# Iteration 158: k=5000, t=160000
# Recognition Rate: 0.2
# Iteration 159: k=5000, t=210000
# Recognition Rate: 0.2
# Iteration 160: k=5000, t=260000
# Recognition Rate: 0.2
# Iteration 161: k=5000, t=310000
# Recognition Rate: 0.2
# Iteration 162: k=5000, t=360000
# Recognition Rate: 0.2
# Iteration 163: k=5000, t=410000
# Recognition Rate: 0.2
# Iteration 164: k=5000, t=460000
# Recognition Rate: 0.2
# Iteration 165: k=5000, t=510000
# Recognition Rate: 0.2
# Iteration 166: k=5000, t=560000
# Recognition Rate: 0.2
# Iteration 167: k=5000, t=610000
# Recognition Rate: 0.2
# Iteration 168: k=5000, t=660000
# Recognition Rate: 0.2
# Iteration 169: k=5000, t=710000
# Recognition Rate: 0.2
# Iteration 170: k=5000, t=760000
# Recognition Rate: 0.2
# Iteration 171: k=5000, t=810000
# Recognition Rate: 0.2
# Iteration 172: k=5000, t=860000
# Recognition Rate: 0.2
# Iteration 173: k=5000, t=910000
# Recognition Rate: 0.2
# Iteration 174: k=5000, t=960000
# Recognition Rate: 0.2
# Iteration 175: k=5000, t=1010000
# Recognition Rate: 0.2
# Iteration 176: k=5000, t=1060000
# Recognition Rate: 0.2
# Iteration 177: k=5000, t=1110000
# Recognition Rate: 0.2
# Iteration 178: k=5000, t=1160000
# Recognition Rate: 0.2
# Iteration 179: k=5000, t=1210000
# Recognition Rate: 0.2
# Iteration 180: k=5000, t=1260000
# Recognition Rate: 0.2
# Iteration 181: k=5000, t=1310000
# Recognition Rate: 0.2
# Iteration 182: k=5000, t=1360000
# Recognition Rate: 0.2
# Iteration 183: k=5000, t=1410000
# Recognition Rate: 0.2
# Iteration 184: k=5000, t=1460000
# Recognition Rate: 0.2
# Iteration 185: k=5500, t=10000
# Recognition Rate: 0.18
# Iteration 186: k=5500, t=60000
# Recognition Rate: 0.2
# Iteration 187: k=5500, t=110000
# Recognition Rate: 0.2
# Iteration 188: k=5500, t=160000
# Recognition Rate: 0.2
# Iteration 189: k=5500, t=210000
# Recognition Rate: 0.2
# Iteration 190: k=5500, t=260000
# Recognition Rate: 0.2
# Iteration 191: k=5500, t=310000
# Recognition Rate: 0.2
# Iteration 192: k=5500, t=360000
# Recognition Rate: 0.2
# Iteration 193: k=5500, t=410000
# Recognition Rate: 0.2
# Iteration 194: k=5500, t=460000
# Recognition Rate: 0.2
# Iteration 195: k=5500, t=510000
# Recognition Rate: 0.2
# Iteration 196: k=5500, t=560000
# Recognition Rate: 0.2
# Iteration 197: k=5500, t=610000
# Recognition Rate: 0.2
# Iteration 198: k=5500, t=660000
# Recognition Rate: 0.2
# Iteration 199: k=5500, t=710000
# Recognition Rate: 0.2
# Iteration 200: k=5500, t=760000
# Recognition Rate: 0.2
# Iteration 201: k=5500, t=810000
# Recognition Rate: 0.2
# Iteration 202: k=5500, t=860000
# Recognition Rate: 0.2
# Iteration 203: k=5500, t=910000
# Recognition Rate: 0.2
# Iteration 204: k=5500, t=960000
# Recognition Rate: 0.2
# Iteration 205: k=5500, t=1010000
# Recognition Rate: 0.2
# Iteration 206: k=5500, t=1060000
# Recognition Rate: 0.2
# Iteration 207: k=5500, t=1110000
# Recognition Rate: 0.2
# Iteration 208: k=5500, t=1160000
# Recognition Rate: 0.2
# Iteration 209: k=5500, t=1210000
# Recognition Rate: 0.2
# Iteration 210: k=5500, t=1260000
# Recognition Rate: 0.2
# Iteration 211: k=5500, t=1310000
# Recognition Rate: 0.2
# Iteration 212: k=5500, t=1360000
# Recognition Rate: 0.2
# Iteration 213: k=5500, t=1410000
# Recognition Rate: 0.2
# Iteration 214: k=5500, t=1460000
# Recognition Rate: 0.2
# Iteration 215: k=6000, t=10000
# Recognition Rate: 0.18
# Iteration 216: k=6000, t=60000
# Recognition Rate: 0.2
# Iteration 217: k=6000, t=110000
# Recognition Rate: 0.2
# Iteration 218: k=6000, t=160000
# Recognition Rate: 0.2
# Iteration 219: k=6000, t=210000
# Recognition Rate: 0.2
# Iteration 220: k=6000, t=260000
# Recognition Rate: 0.2
# Iteration 221: k=6000, t=310000
# Recognition Rate: 0.2
# Iteration 222: k=6000, t=360000
# Recognition Rate: 0.2
# Iteration 223: k=6000, t=410000
# Recognition Rate: 0.2
# Iteration 224: k=6000, t=460000
# Recognition Rate: 0.2
# Iteration 225: k=6000, t=510000
# Recognition Rate: 0.2
# Iteration 226: k=6000, t=560000
# Recognition Rate: 0.2
# Iteration 227: k=6000, t=610000
# Recognition Rate: 0.2
# Iteration 228: k=6000, t=660000
# Recognition Rate: 0.2
# Iteration 229: k=6000, t=710000
# Recognition Rate: 0.2
# Iteration 230: k=6000, t=760000
# Recognition Rate: 0.2
# Iteration 231: k=6000, t=810000
# Recognition Rate: 0.2
# Iteration 232: k=6000, t=860000
# Recognition Rate: 0.2
# Iteration 233: k=6000, t=910000
# Recognition Rate: 0.2
# Iteration 234: k=6000, t=960000
# Recognition Rate: 0.2
# Iteration 235: k=6000, t=1010000
# Recognition Rate: 0.2
# Iteration 236: k=6000, t=1060000
# Recognition Rate: 0.2
# Iteration 237: k=6000, t=1110000
# Recognition Rate: 0.2
# Iteration 238: k=6000, t=1160000
# Recognition Rate: 0.2
# Iteration 239: k=6000, t=1210000
# Recognition Rate: 0.2
# Iteration 240: k=6000, t=1260000
# Recognition Rate: 0.2
# Iteration 241: k=6000, t=1310000
# Recognition Rate: 0.2
# Iteration 242: k=6000, t=1360000
# Recognition Rate: 0.2
# Iteration 243: k=6000, t=1410000
# Recognition Rate: 0.2
# Iteration 244: k=6000, t=1460000
# Recognition Rate: 0.2
# Iteration 245: k=6500, t=10000
# Recognition Rate: 0.2
# Iteration 246: k=6500, t=60000
# Recognition Rate: 0.2
# Iteration 247: k=6500, t=110000
# Recognition Rate: 0.2
# Iteration 248: k=6500, t=160000
# Recognition Rate: 0.2
# Iteration 249: k=6500, t=210000
# Recognition Rate: 0.2
# Iteration 250: k=6500, t=260000
# Recognition Rate: 0.2
# Iteration 251: k=6500, t=310000
# Recognition Rate: 0.2
# Iteration 252: k=6500, t=360000
# Recognition Rate: 0.2
# Iteration 253: k=6500, t=410000
# Recognition Rate: 0.2
# Iteration 254: k=6500, t=460000
# Recognition Rate: 0.2
# Iteration 255: k=6500, t=510000
# Recognition Rate: 0.2
# Iteration 256: k=6500, t=560000
# Recognition Rate: 0.2
# Iteration 257: k=6500, t=610000
# Recognition Rate: 0.2
# Iteration 258: k=6500, t=660000
# Recognition Rate: 0.2
# Iteration 259: k=6500, t=710000
# Recognition Rate: 0.2
# Iteration 260: k=6500, t=760000
# Recognition Rate: 0.2
# Iteration 261: k=6500, t=810000
# Recognition Rate: 0.2
# Iteration 262: k=6500, t=860000
# Recognition Rate: 0.2
# Iteration 263: k=6500, t=910000
# Recognition Rate: 0.2
# Iteration 264: k=6500, t=960000
# Recognition Rate: 0.2
# Iteration 265: k=6500, t=1010000
# Recognition Rate: 0.2
# Iteration 266: k=6500, t=1060000
# Recognition Rate: 0.2
# Iteration 267: k=6500, t=1110000
# Recognition Rate: 0.2
# Iteration 268: k=6500, t=1160000
# Recognition Rate: 0.2
# Iteration 269: k=6500, t=1210000
# Recognition Rate: 0.2
# Iteration 270: k=6500, t=1260000
# Recognition Rate: 0.2
# Iteration 271: k=6500, t=1310000
# Recognition Rate: 0.2
# Iteration 272: k=6500, t=1360000
# Recognition Rate: 0.2
# Iteration 273: k=6500, t=1410000
# Recognition Rate: 0.2
# Iteration 274: k=6500, t=1460000
# Recognition Rate: 0.2
# Iteration 275: k=7000, t=10000
# Recognition Rate: 0.2
# Iteration 276: k=7000, t=60000
# Recognition Rate: 0.2
# Iteration 277: k=7000, t=110000
# Recognition Rate: 0.2
# Iteration 278: k=7000, t=160000
# Recognition Rate: 0.2
# Iteration 279: k=7000, t=210000
